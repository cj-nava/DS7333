# %% [markdown]
# # Case #6
# ## Michael Catalano, Martin Garcia, Jeremy Otsap, Christian Nava

# %% [markdown]
# # Introduction
#
# #### Taken from the abstract of the white paper "Searching for Exotic Particles in High-Energy Physics with Deep Learning", "collisions at high-energy particle colliders are a source of exotic particle discoveries. Finding these rare particles requires solving difficult signal-versus-background classification problems." The authors utilize a deep neural network approach to handle this classification task. From the results of the experiment, it is evident that deep learning approaches like neural networks can improve the power of collider searches for exotic particles, particularly how to classify either a signal versus background classes.
#
# #### As we dig deeper into the methods used by the authors in 2014, its incredible how far neural networks have come. Improvements in libraries, new activation functions and optimizers, and economies of scale have helped pave the way for building competing neural networks at home without the need of multi-core cloud solutions. Standard practices used when the paper was published have changed; modifications to the methods used in the paper might show comparable or even better performance at a fraction of the computation cost.
#
# #### The following analysis replicates the deep learning model from the architecture used in the 2014 white paper, discusses the assumptions and some of the concepts used in the model, and proposes modifications where appropriate. In addition to replicating the model architecture from the paper, we have created a handful of additional models for a comparison using different tuning parameters.

# %% [markdown]
# ### Deep Neural Networks
#
# #### In the paper, the authors build and compare multiple deep neural networks before selecting the best-performing model for use in their final classification tool. In its most simplistic form, a neural network consists of nodes which make up layers of a network. A simple one-layer neural network contains an input layer, hidden layer, and an output layer. All inputs are modified by a weight and summed (linear combination). Finally, an activation function controls the amplitude of the output. The network essentially "learns" the distribution function of the observed data, and iteratively improves its predictive power by batching through training samples.
#
# #### The structure of a neural network dictates the depth and complexity, as "deep" neural networks often have multiple layers. Figure 1 below shows an example of a one-layer neural network.

# %% [markdown]
# ![NN.jpg](attachment:NN.jpg)

# %% [markdown]
# ### Hyperparameters within Neural Network Configurations
#
#  * Learning rate: an important hyperparameter used in the training of neural networks, and is typically between 0 and 1. "The learning rate controls how quickly the model is adapted to the problem. Smaller learning rates require more training epochs given the smaller changes made to the weights after each update, whereas larger learning rates result in rapid changes and require fewer training epochs." So what does this mean, exactly? The learning rate controls the stability of a model; set it too small and the training process could get stuck and our model might not learn. Setting the value too large may result in learning a sub-optimal set of weights too quickly and overfitting might occur.
#
#  * Weight decay coefficient: A parameter used to prevent our model from getting too complex; prevent overfitting by multiplying the sum of squares with a small, aribitrary value. A more technical defintion: "Weight decay specifies regularization in the neural network. During training, a regularization term is added to the network's loss to compute the backpropagation gradient. The weight decay value determines how dominant this regularization term will be in the gradient computation."
#
#  * Activation function: Decides whether a neuron in the hidden layer should be activated based on the calculation of a weighted sum plus a bias term. The purpose of the activation function is to introduce non-linearity into the output of a neuron, else its a linear regression model. "The activation function does the non-linear transformation to the input making it capable to learn and perform more complex tasks." The choice of which activation function to use is dependent on the output of a problem (classification, probabilistic prediction, etc.), however there is no hard or fast rule.
#
#  * Batch size (aka mini-batches): When training a neural network, this is the number of samples that will be sent through the network at one time. Generally, the larger the batch size, the quicker the epochs run. There is a trade-off between batch size and computational resources on the machine one needs to be aware of.
#
#  * Epoch: A single pass of all data through the network. Set in the configuration of your model.
#
#
# ### Paper Methodology and Data
#
# #### The authors select a five-layer neural network with 300 hidden units in each layer, a learning rate of 0.05, and a weight decay coefficient of 1 × 10−5. Going back to Figure 1, we only showed a single-layer network with five hidden units. You can imagine how large this structure would be to visualize with five layers and 300 units each!
#
# #### Neural networks are subject to immense tuning, often governed by time and resources. One universally accepted notion is these networks require large training datasets. For example, the authors used 11 million simulated collision events for benchmarking, with 28 features. The authors split these features into low and high-levels per the amount of discrimination power, though hyper-parameter optimization was performed using the full set of HIGGS features (all 28).
#
# #### The training set consists of 2.6 million examples and 100,000 validation examples. The following hyperparameters are used in training (from the paper):
# * Weights were initialized from a normal distribution with zero mean and standard deviation 0.1 in the first layer, 0.001 in the output layer, and 0.05 all other hidden layers
# * Hidden units all used the tanh activation function
# * Gradient computations were made on mini-batches of size 100
# * A momentum term increased linearly over the first 200 epochs from 0.9 to 0.99, at which point it remained constant
# * The learning rate decayed by a factor of 1.0000002 every batch update until it reached a minimum of 10−6
#
# ##### Sources:
# https://machinelearningmastery.com/understand-the-dynamics-of-learning-rate-on-deep-learning-neural-networks/#:~:text=The%20amount%20that%20the%20weights,range%20between%200.0%20and%201.0.
# https://stats.stackexchange.com/questions/273189/what-is-the-weight-decay-loss#:~:text=Weight%20decay%20specifies%20regularization%20in,be%20in%20the%20gradient%20computation.
# https://www.geeksforgeeks.org/activation-functions-neural-networks/

# %% [markdown]
# ### Evaluation Metrics -AUC

# %% [markdown]
# Performance is measured using a Receiver Operating Characteristic (ROC) curves that looks at a benchmark boosted decision tree, shallow and deep neural networks with three additional layers each based on features. The results for the table on the left look at the results for the Higgs and right for the SUSY benchmark. The AUC under the context of this study looks at classification accuracy for the new particle, Higgs Boson. The second benchmark is also a classitification tasks between two processes with the goal of identifying those of the new particles. The goal for this metric is to have the largest area under the curve which demonstrate higher accuracy at different thresholds, or measure of true positive rate against false positive rate at varying settings for our model.

# %% [markdown]
# ![alt text](NN_AUC.jpg "Title")

# %% [markdown]
# Sources: https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc

# %% [markdown]
# ## 1. Replicate results from paper

# %%
import os
import logging
import logging.config
import numpy as np 
import pandas as pd
import tensorflow as tf
import pandas as pd 
import pandas_profiling as pp
import matplotlib.pyplot as plt
import seaborn as sns

# Remove scientific notation
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
# From https://arxiv.org/abs/1402.4735

# %% [markdown]
# #### Get working Directory

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Mike'

# %% [markdown]
# #### Get Data

# %%
# Downloads a file from a URL if it not already in the cache. Will save in .keraset/dataset folder
gz = tf.keras.utils.get_file('HIGGS.csv.gz', 'http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz')

# %% [markdown]
# Contains 11,000,000 examples, each with 28 features, and a binary class label.

# %%
higgs = pd.read_csv('.keras/datasets/HIGGS.csv.gz',nrows = 250000, skiprows = 10)

# %% [markdown]
# Sample of 250,000 records from the first 2.5 million (skiprows of 10)

# %%
higgs.head()
# Out:
#    1.000000000000000000e+00  9.459739923477172852e-01  \
# 0                   0.00000                   0.73936
# 1                   1.00000                   1.38410
# 2                   1.00000                   1.38355
# 3                   1.00000                   1.34365
# 4                   0.00000                   0.54701
#
#    1.111244320869445801e+00  1.218337059020996094e+00  \
# 0                  -0.17829                   0.82993
# 1                   0.11682                  -1.17988
# 2                   0.88918                   0.61853
# 3                   0.83853                  -1.06114
# 4                  -0.34971                  -0.64666
#
#    9.076390862464904785e-01  8.215369582176208496e-01  \
# 0                   0.50454                  -0.13022
# 1                   0.76291                  -0.07978
# 2                   1.08155                   0.34461
# 3                   2.47202                  -0.57263
# 4                   2.04046                   0.27646
#
#    1.153243303298950195e+00  -3.654202818870544434e-01  \
# 0                   0.96105                   -0.35552
# 1                   1.01986                    0.87732
# 2                   0.95638                    0.85454
# 3                   1.51271                    1.14369
# 4                   0.54470                    0.83870
#
#    -1.566054821014404297e+00  0.000000000000000000e+00  ...  \
# 0                   -1.71740                   2.17308  ...
# 1                    1.27689                   2.17308  ...
# 2                   -1.12921                   2.17308  ...
# 3                    0.85556                   0.00000  ...
# 4                    1.72870                   0.00000  ...
#
#    -4.510180354118347168e-01  6.365344673395156860e-02  \
# 0                    0.77406                   0.39882
# 1                    0.84652                   0.50481
# 2                   -1.63613                   1.14407
# 3                    2.39640                   0.75729
# 4                   -0.62924                   1.57079
#
#    3.101961374282836914e+00  8.290241360664367676e-01  \
# 0                   3.10196                   0.94454
# 1                   3.10196                   0.95932
# 2                   0.00000                   0.52224
# 3                   0.00000                   0.93402
# 4                   3.10196                   0.68943
#
#    9.806482791900634766e-01  9.943597912788391113e-01  \
# 0                   1.02626                   0.98220
# 1                   0.80738                   1.19181
# 2                   0.73764                   0.98620
# 3                   0.84471                   1.07784
# 4                   0.86723                   1.08249
#
#    9.082478284835815430e-01  7.758789062500000000e-01  \
# 0                   0.54211                   1.25098
# 1                   1.22121                   0.86114
# 2                   1.34962                   0.81279
# 3                   1.40018                   0.94777
# 4                   0.66414                   0.35411
#
#    7.833113670349121094e-01  7.251217961311340332e-01
# 0                   0.83004                   0.76131
# 1                   0.92934                   0.83830
# 2                   0.95341                   0.77972
# 3                   1.00761                   0.90102
# 4                   0.57995                   0.81727
#
# [5 rows x 29 columns]

# %% [markdown]
# #### Preprocessing

# %%
# Rename columns
higgs.columns = ['label','lepton_pT','lepton_eta','lepton_phi','missing_energy_magnitude','missing_energy_phi','jet_1_pt','jet_1_eta','jet_1_phi','jet_1_b_tag','jet_2_pt','jet_2_eta','jet_2_phi','jet_2_b_tag','jet_3_pt','jet_3_eta','jet_3_phi','jet_3_b-tag','jet_4_pt','jet_4_eta','jet_4_phi','jet_4_b_tag','m_jj','m_jjj','m_lv','m_jlv','m_bb','m_wbb','m_wwbb']

# %%
higgs.head()
# Out:
#     label  lepton_pT  lepton_eta  lepton_phi  missing_energy_magnitude  \
# 0 0.00000    0.73936    -0.17829     0.82993                   0.50454
# 1 1.00000    1.38410     0.11682    -1.17988                   0.76291
# 2 1.00000    1.38355     0.88918     0.61853                   1.08155
# 3 1.00000    1.34365     0.83853    -1.06114                   2.47202
# 4 0.00000    0.54701    -0.34971    -0.64666                   2.04046
#
#    missing_energy_phi  jet_1_pt  jet_1_eta  jet_1_phi  jet_1_b_tag  ...  \
# 0            -0.13022   0.96105   -0.35552   -1.71740      2.17308  ...
# 1            -0.07978   1.01986    0.87732    1.27689      2.17308  ...
# 2             0.34461   0.95638    0.85454   -1.12921      2.17308  ...
# mean       1.03333      0.95999
# std        0.36465      0.31314
# min        0.30335      0.35094
# 25%        0.81977      0.77038
# 50%        0.94715      0.87169
# 75%        1.14008      1.05973
# max        8.43236      6.01565
#
# [8 rows x 29 columns]

# %%
higgs.dtypes
# Out:
# label                       float64
# lepton_pT                   float64
# lepton_eta                  float64
# lepton_phi                  float64
# missing_energy_magnitude    float64
# missing_energy_phi          float64
# jet_1_pt                    float64
# jet_1_eta                   float64
# jet_1_phi                   float64
# jet_1_b_tag                 float64
# jet_2_pt                    float64
# jet_2_eta                   float64
# jet_2_phi                   float64
# jet_2_b_tag                 float64
# jet_3_pt                    float64
# jet_3_eta                   float64
# jet_3_phi                   float64
# jet_3_b-tag                 float64
# jet_4_pt                    float64
# jet_4_eta                   float64
# jet_4_phi                   float64
# jet_4_b_tag                 float64
# m_jj                        float64
# m_jjj                       float64
# m_lv                        float64
# m_jlv                       float64
# m_bb                        float64
# m_wbb                       float64
# m_wwbb                      float64
# dtype: object

# %%
#change label to int
higgs["label"] = higgs["label"].astype(int)

# %%
dataset = higgs.values

# %%
# split into input (X) and output (Y) arrays
X = dataset[:,1:29].astype(float)
Y = dataset[:,0]

# %%
# visualize data
X[0:3]
# Out:
# array([[ 0.73935676, -0.17829043,  0.82993424,  0.50453907, -0.13021675,
#          0.96105134, -0.35551798, -1.71739936,  2.17307615,  0.62095606,
#         -0.48174104, -1.19919324,  0.        ,  0.9826014 ,  0.08118503,
#         -0.29032364,  0.        ,  1.06466293,  0.77406496,  0.39882034,
#          3.10196137,  0.94453603,  1.02626061,  0.98219675,  0.54211468,
#          1.25097895,  0.83004463,  0.76130795],
#        [ 1.3840977 ,  0.11682209, -1.17987895,  0.76291257, -0.07978227,
#          1.01986313,  0.87731826,  1.27688718,  2.17307615,  0.3312521 ,
#          1.40952349, -1.47438884,  0.        ,  1.28273821,  0.73747438,
#         -0.22541961,  0.        ,  1.55975306,  0.84652054,  0.50480855,
#          3.10196137,  0.95932466,  0.80737603,  1.19181359,  1.22121036,
#          0.86114126,  0.9293409 ,  0.83830237],
#        [ 1.38354874,  0.88917929,  0.61853206,  1.08154702,  0.34460557,
#          0.95637935,  0.85454297, -1.12920702,  2.17307615,  0.54566574,
#         -0.30786517, -0.62327981,  2.21487212,  0.34825712,  1.02420259,
#          0.18407767,  0.        ,  0.7813369 , -1.63612556,  1.14406729,
#          0.        ,  0.52223849,  0.73763853,  0.98619956,  1.34961569,
#          0.81278789,  0.95340645,  0.77972263]])

# %%
Y[0:3]
# Out:
# array([0., 1., 1.])

# %% [markdown]
# ### Normalization
#
# #### Normalizing the data generally speeds up learning and leads to faster convergence (the network is more able to find a reasonable minima in its loss function.)

# %%
from sklearn import preprocessing

# Normalize X values
normalized_X = preprocessing.normalize(X, norm='l2', axis=1, copy=True, return_norm=False)

# %%
normalized_X[0:3]
# Out:
# array([[ 0.13295555, -0.03206125,  0.14924374,  0.09072923, -0.02341635,
#          0.172822  , -0.06393137, -0.30883302,  0.39077555,  0.11166403,
#         -0.08662956, -0.2156461 ,  0.        ,  0.17669726,  0.01459918,
#         -0.05220773,  0.        ,  0.19145406,  0.13919699,  0.07171826,
#          0.55781325,  0.16985212,  0.18454832,  0.17662449,  0.0974863 ,
#          0.22495852,  0.14926359,  0.13690295],
#        [ 0.22335446,  0.0188518 , -0.19039929,  0.12311264, -0.01287462,
#          0.16457724,  0.1415745 ,  0.20605369,  0.3506734 ,  0.05345478,
#          0.22745747, -0.23792491,  0.        ,  0.20699789,  0.11900763,
#         -0.03637639,  0.        ,  0.2517003 ,  0.13660462,  0.08146191,
#          0.50056936,  0.15480803,  0.13028779,  0.19232521,  0.19706902,
#          0.13896399,  0.14996949,  0.13527844],
#        [ 0.25562701,  0.1642864 ,  0.11428112,  0.19982862,  0.06366996,
#          0.17670241,  0.15788693, -0.20863437,  0.40150155,  0.10081821,
#         -0.05688174, -0.11515833,  0.40922385,  0.06434463,  0.18923356,
#          0.03401053,  0.        ,  0.14436124, -0.30229357,  0.21137998,
#          0.        ,  0.09648975,  0.13628745,  0.18221205,  0.24935748,
#          0.15017219,  0.17615313,  0.14406299]])

# %% [markdown]
# ## Neural Network Model Building

# %% [markdown]
# #### Model replication from the paper

# %%
# train/test split
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(normalized_X, Y, test_size=0.10, random_state=1776)

# 225,000 samples will be training, 25,000 will be held out for validation

# %%
from time import time
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping
es = EarlyStopping(min_delta=0.001,patience=10)

# early stopping implemented to avoid overfitting. Set the limit with min_delta - the patience tells you the number of epochs to run before stopping.
# So you'd interpret this as - if the loss of the epoch does not change (improve) at the thousanth decimal point for 10 straight epochs, then stop training.

# %%
# build model architecture here and set hyperparameters

from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import add
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import backend as K

lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.05,
    decay_steps=10000,
    decay_rate=1.0000002)

model1 = Sequential()
model1.add(Dense(300, input_dim=28, activation='tanh'))
model1.add(Dense(300, activation='tanh'))
model1.add(Dense(300, activation='tanh'))
model1.add(Dense(300, activation='tanh'))
model1.add(Dense(1, activation='sigmoid'))
# Compile model

model1.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=lr_schedule, momentum=0.9),
              loss='binary_crossentropy',metrics=['accuracy'])

# %%
# prints out the number of weights in your NN
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 300)               8700
# _________________________________________________________________
# dense_1 (Dense)              (None, 300)               90300
# _________________________________________________________________
# dense_2 (Dense)              (None, 300)               90300
# _________________________________________________________________
# dense_3 (Dense)              (None, 300)               90300
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 279,901
# Trainable params: 279,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
history1 = model1.fit(x_train, y_train, validation_data=(x_test,y_test), epochs=100, batch_size=500,callbacks=[es])
# Out:
# Epoch 1/100
# 450/450 [==============================] - 4s 8ms/step - loss: 0.6580 - accuracy: 0.6038 - val_loss: 0.6672 - val_accuracy: 0.5773
# Epoch 2/100
# 450/450 [==============================] - 3s 7ms/step - loss: 0.6477 - accuracy: 0.6208 - val_loss: 0.6525 - val_accuracy: 0.6176
# Epoch 3/100
# 450/450 [==============================] - 3s 7ms/step - loss: 0.6446 - accuracy: 0.6258 - val_loss: 0.6414 - val_accuracy: 0.6296
# Epoch 4/100
# 450/450 [==============================] - 3s 8ms/step - loss: 0.6423 - accuracy: 0.6294 - val_loss: 0.6411 - val_accuracy: 0.6301
# Epoch 5/100
# 450/450 [==============================] - 3s 7ms/step - loss: 0.6415 - accuracy: 0.6317 - val_loss: 0.6378 - val_accuracy: 0.6374
# Epoch 6/100
# 450/450 [==============================] - 3s 8ms/step - loss: 0.6405 - accuracy: 0.6343 - val_loss: 0.6382 - val_accuracy: 0.6356
# Epoch 7/100
# 450/450 [==============================] - 3s 7ms/step - loss: 0.6406 - accuracy: 0.6340 - val_loss: 0.6387 - val_accuracy: 0.6360
# Epoch 8/100
# 450/450 [==============================] - 3s 7ms/step - loss: 0.6389 - accuracy: 0.6358 - val_loss: 0.6365 - val_accuracy: 0.6352
# Epoch 9/100
# 450/450 [==============================] - 3s 8ms/step - loss: 0.6316 - accuracy: 0.6401 - val_loss: 0.6242 - val_accuracy: 0.6523
# Epoch 10/100
# 450/450 [==============================] - 3s 7ms/step - loss: 0.
100
# 450/450 [==============================] - 3s 8ms/step - loss: 0.5356 - accuracy: 0.7258 - val_loss: 0.5359 - val_accuracy: 0.7249
# Epoch 73/100
# 450/450 [==============================] - 3s 7ms/step - loss: 0.5345 - accuracy: 0.7267 - val_loss: 0.5516 - val_accuracy: 0.7152
# Epoch 74/100
# 450/450 [==============================] - 3s 8ms/step - loss: 0.5337 - accuracy: 0.7273 - val_loss: 0.5325 - val_accuracy: 0.7281
# Epoch 75/100
# 450/450 [==============================] - 3s 7ms/step - loss: 0.5334 - accuracy: 0.7270 - val_loss: 0.5349 - val_accuracy: 0.7269
# Epoch 76/100
# 450/450 [==============================] - 3s 8ms/step - loss: 0.5321 - accuracy: 0.7279 - val_loss: 0.5327 - val_accuracy: 0.7290
# Epoch 77/100
# 450/450 [==============================] - 3s 8ms/step - loss: 0.5323 - accuracy: 0.7284 - val_loss: 0.5403 - val_accuracy: 0.7237
# Epoch 78/100
# 450/450 [==============================] - 3s 7ms/step - loss: 0.5320 - accuracy: 0.7276 - val_loss: 0.5346 - val_accuracy: 0.7275
# Epoch 79/100
# 450/450 [==============================] - 3s 7ms/step - loss: 0.5309 - accuracy: 0.7288 - val_loss: 0.5385 - val_accuracy: 0.7245
# Epoch 80/100
# 450/450 [==============================] - 3s 8ms/step - loss: 0.5305 - accuracy: 0.7297 - val_loss: 0.5335 - val_accuracy: 0.7272
# Epoch 81/100
# 450/450 [==============================] - 3s 8ms/step - loss: 0.5303 - accuracy: 0.7285 - val_loss: 0.5315 - val_accuracy: 0.7284
# Epoch 82/100
# 450/450 [==============================] - 3s 8ms/step - loss: 0.5293 - accuracy: 0.7306 - val_loss: 0.5404 - val_accuracy: 0.7226
# Epoch 83/100
# 450/450 [==============================] - 3s 8ms/step - loss: 0.5290 - accuracy: 0.7300 - val_loss: 0.5344 - val_accuracy: 0.7278
# Epoch 84/100
# 450/450 [==============================] - 3s 7ms/step - loss: 0.5284 - accuracy: 0.7308 - val_loss: 0.5358 - val_accuracy: 0.7278

# %%
# build ROC curve metric
from sklearn.metrics import roc_curve

y_pred_keras = model1.predict(x_test).ravel()
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test, y_pred_keras)

# %%
# auc metric for model 1
from sklearn.metrics import auc
auc_keras = auc(fpr_keras, tpr_keras)
auc_keras
# Out:
# 0.8037995636200286

# %% [markdown]
# 80% AUC using the book's parameters

# %%
# accuracy
scores_rnn = model1.evaluate(x_test, y_test, verbose=0)
print('Test accuracy:', scores_rnn[1])
# Out:
# Test accuracy: 0.7278000116348267

# %%
# summarize history for accuracy
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# I'll use a baseline Random Forest Classifier to compare with the paper's NN

# %%
from sklearn.ensemble import RandomForestClassifier
# Supervised transformation based on random forests - my simple model to compare with
rf = RandomForestClassifier(max_depth=10, n_estimators=30)
rf.fit(x_train, y_train)

y_pred_rf = rf.predict_proba(x_test)[:, 1]
fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test, y_pred_rf)
auc_rf = auc(fpr_rf, tpr_rf)

# %%
# ROC curve for both the paper's neural network and a baseline RF model

# %matplotlib inline
from matplotlib import pyplot as plt

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='DN (Paper) (area = {:.3f})'.format(auc_keras))
plt.plot(fpr_rf, tpr_rf, label='RF (area = {:.3f})'.format(auc_rf))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Suggestions for Improvement
#
# * Use another optimizer (like ADAM)
# * Adding other regularization techniques besides dropout (L1, L2, etc. weight decay, label smoothing, etc.)
# * Use another activation (like ReLu)
# * Add dropouts after every dense layer
# * Use some kind of ensemble AutoML model in H2O

# %% [markdown]
# #### NN #2: Playing around with different parameters

# %%
# train/test split (should match above)
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(normalized_X, Y, test_size=0.10, random_state=1776)

# %%
from time import time
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping
es = EarlyStopping(min_delta=0.001,patience=10)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import add, Input
from tensorflow.keras.layers import Embedding, Dense, Dropout, LSTM, TimeDistributed, Bidirectional, Lambda
from tensorflow.keras.layers import SimpleRNN as RNN

model2 = Sequential()
model2.add(Dense(100, input_dim=28, activation='relu'))
model2.add(Dropout(0.2))
model2.add(Dense(50, activation='relu'))
model2.add(Dropout(0.2))
model2.add(Dense(50, activation='relu'))
model2.add(Dropout(0.2))
model2.add(Dense(50, activation='relu'))
model2.add(Dropout(0.2))
model2.add(Dense(1, activation='sigmoid'))
# Compile model
model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# We've done a few things differently in this model, namely used a different activation function, a different optimizer, lowered the neurons in each hidden layer, and added a dropout after every additional hidden layer. Let's see how the model performs.

# %%
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None,
300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5457 - accuracy: 0.7196 - val_loss: 0.5353 - val_accuracy: 0.7279
# Epoch 70/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5452 - accuracy: 0.7197 - val_loss: 0.5328 - val_accuracy: 0.7297
# Epoch 71/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5457 - accuracy: 0.7190 - val_loss: 0.5347 - val_accuracy: 0.7279
# Epoch 72/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5453 - accuracy: 0.7197 - val_loss: 0.5341 - val_accuracy: 0.7276
# Epoch 73/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5451 - accuracy: 0.7204 - val_loss: 0.5336 - val_accuracy: 0.7282
# Epoch 74/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5450 - accuracy: 0.7200 - val_loss: 0.5316 - val_accuracy: 0.7296
# Epoch 75/300
# 450/450 [==============================] - 3s 6ms/step - loss: 0.5451 - accuracy: 0.7200 - val_loss: 0.5324 - val_accuracy: 0.7289
# Epoch 76/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.5438 - accuracy: 0.7219 - val_loss: 0.5336 - val_accuracy: 0.7261
# Epoch 77/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5445 - accuracy: 0.7208 - val_loss: 0.5337 - val_accuracy: 0.7277
# Epoch 78/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5435 - accuracy: 0.7215 - val_loss: 0.5333 - val_accuracy: 0.7299
# Epoch 79/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5441 - accuracy: 0.7205 - val_loss: 0.5333 - val_accuracy: 0.7268
# Epoch 80/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5436 - accuracy: 0.7212 - val_loss: 0.5312 - val_accuracy: 0.7290
# Epoch 81/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5437 - accuracy: 0.7206 - val_loss: 0.5339 - val_accuracy: 0.7283
# Epoch 82/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5435 - accuracy: 0.7212 - val_loss: 0.5331 - val_accuracy: 0.7277
# Epoch 83/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5432 - accuracy: 0.7218 - val_loss: 0.5305 - val_accuracy: 0.7309
# Epoch 84/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5434 - accuracy: 0.7220 - val_loss: 0.5325 - val_accuracy: 0.7305
# Epoch 85/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5428 - accuracy: 0.7203 - val_loss: 0.5312 - val_accuracy: 0.7282
# Epoch 86/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5428 - accuracy: 0.7219 - val_loss: 0.5302 - val_accuracy: 0.7305
# Epoch 87/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5427 - accuracy: 0.7212 - val_loss: 0.5302 - val_accuracy: 0.7296
# Epoch 88/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.5427 - accuracy: 0.7224 - val_loss: 0.5335 - val_accuracy: 0.7297
# Epoch 89/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.5425 - accuracy: 0.7225 - val_loss: 0.5300 - val_accuracy: 0.7298
# Epoch 90/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.5420 - accuracy: 0.7221 - val_loss: 0.5293 - val_accuracy: 0.7314
# Epoch 91/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.5412 - accuracy: 0.7230 - val_loss: 0.5282 - val_accuracy: 0.7311
# Epoch 92/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5418 - accuracy: 0.7228 - val_loss: 0.5291 - val_accuracy: 0.7291
# Epoch 93/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.5417 - accuracy: 0.7219 - val_loss: 0.5300 - val_accuracy: 0.7305
# Epoch 94/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.5419 - accuracy: 0.7212 - val_loss: 0.5302 - val_accuracy: 0.7275
# Epoch 95/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.5415 - accuracy: 0.7231 - val_loss: 0.5299 - val_accuracy: 0.7307
# Epoch 96/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5409 - accuracy: 0.7228 - val_loss: 0.5291 - val_accuracy: 0.7301
# Epoch 97/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5404 - accuracy: 0.7231 - val_loss: 0.5312 - val_accuracy: 0.7304
# Epoch 98/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5402 - accuracy: 0.7230 - val_loss: 0.5310 - val_accuracy: 0.7310
# Epoch 99/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5408 - accuracy: 0.7235 - val_loss: 0.5297 - val_accuracy: 0.7303
# Epoch 100/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5401 - accuracy: 0.7240 - val_loss: 0.5275 - val_accuracy: 0.7318
# Epoch 101/300
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5407 - accuracy: 0.7240 - val_loss: 0.5292 - val_accuracy: 0.7293

# %%
from sklearn.metrics import roc_curve

y_pred_keras = model2.predict(x_test).ravel()
fpr_keras2, tpr_keras2, thresholds_keras2 = roc_curve(y_test, y_pred_keras)

# %%
# auc metric for model 2
from sklearn.metrics import auc
auc_keras2 = auc(fpr_keras2, tpr_keras2)
auc_keras2
# Out:
# 0.8099249490622644

# %% [markdown]
# #### Seeing a negligible improvement in AUC by using different hyperparameters

# %%
# Accuracy
scores_rnn = model2.evaluate(x_test, y_test, verbose=0)
print('Test accuracy:', scores_rnn[1])
# Out:
# Test accuracy: 0.7292799949645996

# %% [markdown]
# #### Comparisons Between NN Models

# %%
# ROC curve using all three models: paper architecture, RF, and optimized NN
# %matplotlib inline
from matplotlib import pyplot as plt

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='DN (Paper) (area = {:.3f})'.format(auc_keras))
plt.plot(fpr_keras2, tpr_keras2, label='DN (Optimized) (area = {:.3f})'.format(auc_keras2))
plt.plot(fpr_rf, tpr_rf, label='RF (area = {:.3f})'.format(auc_rf))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %%
# summarized history for accuracy - both models
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['paper train', 'paper test','opt. train','opt. test'], loc='lower right')
plt.show()

# %%
# summarized history for loss - both models
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['paper train', 'paper test','opt. train','opt. test'], loc='upper right')
plt.show()

# %% [markdown]
# #### NN #3: Let's see what h2o can do for us

# %%
import h2o
from h2o.estimators.deeplearning import H2ODeepLearningEstimator
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
h2o.init()           
h2o.remove_all()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  ---------------------------------------------------------
# H2O_cluster_uptime:         11 hours 10 mins
# H2O_cluster_timezone:       America/Chicago
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.30.0.6
# H2O_cluster_version_age:    22 days
# H2O_cluster_name:           H2O_from_python_Mike_gip6tu
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.347 Gb
# H2O_cluster_total_cores:    12
# H2O_cluster_allowed_cores:  12
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.7.6 final
# --------------------------  ---------------------------------------------------------

# %%
hf = h2o.H2OFrame(higgs)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
# change label to a factor so h2o recognizes it as a classification problem
hf['label'] = hf['label'].asfactor()

# %%
train, valid = hf.split_frame([0.9])
higgs_X = hf.col_names[1:]
higgs_y = hf.col_names[0]

# %%
# check out our training set
train.describe()
# Out:
# Rows:224930
# Cols:29
# <table>
# <thead>
# <tr><th>       </th><th>label  </th><th>lepton_pT          </th><th>lepton_eta            </th><th>lepton_phi            </th><th>missing_energy_magnitude  </th><th>missing_energy_phi    </th><th>jet_1_pt           </th><th>jet_1_eta            </th><th>jet_1_phi             </th><th>jet_1_b_tag       </th><th>jet_2_pt           </th><th>jet_2_eta            </th><th>jet_2_phi             </th><th>jet_2_b_tag       </th><th>jet_3_pt           </th><th>jet_3_eta            </th><th>jet_3_phi             </th><th>jet_3_b-tag       </th><th>jet_4_pt           </th><th>jet_4_eta            </th><th>jet_4_phi              </th><th>jet_4_b_tag       </th><th>m_jj               </th><th>m_jjj             </th><th>m_lv               </th><th>m_jlv              </th><th>m_bb               </th><th>m_wbb              </th><th>m_wwbb             </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>enum   </td><td>real               </td><td>real                  </td><td>real                  </td><td>real                      </td><td>real                  </td><td>real               </td><td>real                 </td><td>real                  </td><td>real              </td><td>real               </td><td>real                 </td><td>real                  </td><td>real              </td><td>real               </td><td>real                 </td><td>real                  </td><td>real              </td><td>real               </td><td>real                 </td><td>real                   </td><td>real              </td><td>real               </td><td>real              </td><td>real               </td><td>real               </td><td>real               </td><td>real               </td><td>real               </td></tr>
# <tr><td>mins   </td><td>       </td><td>0.27469664812088007</td><td>-2.434976100921631    </td><td>-1.7425082921981812   </td><td>0.0012828720500692723     </td><td>-1.7439435720443723   </td><td>0.13997583091259003</td><td>-2.9697251319885254  </td><td>-1.7412374019622805   </td><td>0.0               </td><td>0.18910706043243408</td><td>-2.913089513778687   </td><td>-1.7423716783523555   </td><td>0.0               </td><td>0.2636076211929321 </td><td>-2.7296628952026367  </td><td>-1.7420687675476072   </td><td>0.0               </td><td>0.36535415053367615</td><td>-2.4972648620605473  </td><td>-1.742690801620483     </td><td>0.0               </td><td>0.10967338830232622</td><td>0.2453176081180573</td><td>0.13301192224025726</td><td>0.15747258067131042</td><td>0.04812500998377799</td><td>0.30334970355033875</td><td>0.35093879699707037</td></tr>
# <tr><td>missing</td><td>0      </td><td>0                  </td><td>0                     </td><td>0                     </td><td>0                         </td><td>0                     </td><td>0                  </td><td>0                    </td><td>0                     </td><td>0                 </td><td>0                  </td><td>0                    </td><td>0                     </td><td>0                 </td><td>0                  </td><td>0                    </td><td>0                     </td><td>0                 </td><td>0                  </td><td>0                    </td><td>0                      </td><td>0                 </td><td>0                  </td><td>0                 </td><td>0                  </td><td>0                  </td><td>0                  </td><td>0                  </td><td>0                  </td></tr>
# <tr><td>0      </td><td>0      </td><td>0.739356756210327  </td><td>-0.1782904267311096   </td><td>0.8299342393875122    </td><td>0.5045390725135802        </td><td>-0.13021674752235413  </td><td>0.961051344871521  </td><td>-0.3555179834365845  </td><td>-1.7173993587493894   </td><td>2.1730761528015137</td><td>0.6209560632705688 </td><td>-0.4817410409450531  </td><td>-1.199193239212036    </td><td>0.0               </td><td>0.9826014041900634 </td><td>0.08118502795696257  </td><td>-0.29032364487648005  </td><td>0.0               </td><td>1.0646629333496092 </td><td>0.7740649580955506   </td><td>0.3988203406333923     </td><td>3.1019613742828365</td><td>0.9445360302925108 </td><td>1.0262606143951416</td><td>0.9821967482566832 </td><td>0.5421146750450134 </td><td>1.250978946685791  </td><td>0.8300446271896361 </td><td>0.761307954788208  </td></tr>
# <tr><td>1      </td><td>1      </td><td>1.3840976953506468 </td><td>0.11682209372520444   </td><td>-1.1798789501190183   </td><td>0.7629125714302065        </td><td>-0.07978226989507675  </td><td>1.0198631286621092 </td><td>0.8773182630538942

# %%
higgs_model_v1 = H2ODeepLearningEstimator(model_id = 'higgs_v1', epochs = 10, variable_importances = False)
higgs_model_v1.train(higgs_X, higgs_y, training_frame = train, validation_frame = valid)
print(higgs_model_v1)
# Out:
# deeplearning Model Build progress: |██████████████████████████████████████| 100%
# Model Details
# =============
# H2ODeepLearningEstimator :  Deep Learning
# Model Key:  higgs_v1
#
#
# Status of Neuron Layers: predicting label, 2-class classification, bernoulli distribution, CrossEntropy loss, 46,402 weights/biases, 556.3 KB, 2,300,441 training samples, mini-batch size 1
#      layer  units       type dropout      l1      l2 mean_rate rate_rms  \
# 0        1     28      Input 0.00000
# 1        2    200  Rectifier 0.00000 0.00000 0.00000   0.00546  0.00204
# 2        3    200  Rectifier 0.00000 0.00000 0.00000   0.04187  0.06285
# 3        4      2    Softmax         0.00000 0.00000   0.00306  0.00200
#
#   momentum mean_weight weight_rms mean_bias bias_rms
# 0
# 1  0.00000    -0.02755    0.31289  -0.36415  0.24156
# 2  0.00000    -0.05858    0.12697   0.58977  0.22731
# 3  0.00000    -0.01264    0.35545   0.22414  0.21250
# ModelMetricsBinomial: deeplearning
# ** Reported on train data. **
#
# MSE: 0.16336761307879505
# RMSE: 0.40418759639404456
# LogLoss: 0.49193628152266206
# Mean Per-Class Error: 0.24373682092633508
# AUC: 0.8391347566024584
# AUCPR: 0.8523043799624148
# Gini: 0.6782695132049168
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.40823659445181637:
#                   0          1   Error              Rate
# 0      0 2897.00000 1801.00000  0.3834   (1801.0/4698.0)
# 1      1  733.00000 4526.00000  0.1394    (733.0/5259.0)
# 2  Total 3630.00000 6327.00000  0.2545   (2534.0/9957.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold      value       idx
# 0                        max f1    0.40824    0.78129 241.00000
# 1                        max f2    0.15889    0.87159 336.00000
# 2                  max f0point5    0.64263    0.77970 149.00000
# 3                  max accuracy    0.51236    0.75756 201.00000
# 4                 max precision    0.99770    1.00000   0.00000
# 5                    max recall    0.00307    1.00000 398.00000
# 6               max specificity    0.99770    1.00000   0.00000
# 7              max absolute_mcc    0.51236    0.51315 201.00000
# 8    max min_per_class_accuracy    0.53632    0.75433 192.00000
# 9   max mean_per_class_accuracy    0.51236    0.75626 201.00000
# 10                      max tns    0.99770 4698.00000   0.00000
# 11                      max fns    0.99770 5248.00000   0.00000
# 12                      max fps    0.00118 4698.00000 399.00000
# 13                      max tps    0.00307 5259.00000 398.00000
# 14                      max tnr    0.99770    1.00000   0.00000
# 15                      max fnr    0.99770    0.99791   0.00000
# 16                      max fpr    0.00118    1.00000 399.00000
# 17                      max tpr    0.00307    1.00000 398.00000
# Gains/Lift Table: Avg response rate: 52.82 %, avg score: 53.00 %
#     group  cumulative_data_fraction  lower_threshold    lift  cumulative_lift  \
# 0       1                   0.01004          0.98612 1.89333          1.89333
# 1       2                   0.02009          0.97852 1.81759          1.85546
# 2       3                   0.03003          0.97070 1.85508          1.85533
# 3       4                   0.04007          0.96434 1.83653          1.85062
# 4       5                   0.05002          0.95612 1.81683          1.84390
# 5       6                   0.10003          0.92150 1.76406          1.80398
# 6       7                   0.15005          0.87975 1.73745          1.78180
# 7       8                   0.20006          0.83339 1.63480          1.74505
# 8       9                   0.29999          0.73890 1.52227          1.67084
# 9      10                   0.40002          0.64508 1.26032          1.56819
# 10     11                   0.50005          0.54919 1.13105          1.48074
# 11     12                   0.59998          0.44553 0.92668          1.38846
# 12     13                   0.70001          0.33484 0.73186          1.29463
# 13     14                   0.79994          0.22844 0.52709          1.19875
# 14     15                   0.89997          0.10745 0.31936          1.10101
# 15     16                   1.00000          0.00001 0.09124          1.00000
#
#     response_rate   score  cumulative_response_rate  cumulative_score  \
# 0         1.00000 0.99129                   1.00000           0.99129
# 1         0.96000 0.98246                   0.98000           0.98688
# 2         0.97980 0.97462                   0.97993           0.98282
# 3         0.97000 0.96716                   0.97744           0.97890
# 4         0.95960 0.96040                   0.97390           0.97522
# 5         0.93173 0.93892                   0.95281           0.95707
# 6         0.91767 0.90101                   0.94110           0.93838
# 7         0.86345 0.85720                   0.92169           0.91809
# 8         0.80402 0.78641                   0.88249           0.87422
# 9         0.66566 0.69169                   0.82827           0.82858
# 10        0.59739 0.59716                   0.78208           0.78229
# 11        0.48945 0.49755                   0.73334           0.73486
# 12        0.38655 0.39078                   0.68379           0.68569
# 13        0.27839 0.28179                   0.63315           0.63524
# 14        0.16867 0.16805                   0.58152           0.58331
# 15        0.04819 0.05066                   0.52817           0.53003
#
#     capture_rate  cumulative_capture_rate      gain  cumulative_gain  \
# 0        0.01902                  0.01902  89.33257         89.33257
# 1        0.01825                  0.03727  81.75927         85.54592
# 2        0.01844                  0.05571  85.50767         85.53326
# 3        0.01844                  0.07416  83.65260         85.06191
# 4        0.01806                  0.09222  81.68277         84.39016
# 5        0.08823                  0.18045  76.40625         80.39820
# 6        0.08690                  0.26735  73.74495         78.18045
# 7        0.08176                  0.34912  63.47993         74.50532
# 8        0.15212                  0.50124  52.22719         67.08425
# 9        0.12607                  0.62731  26.03162         56.81852
# 10       0.11314                  0.74044  13.10530         48.07412
# 11       0.09260                  0.83305  -7.33170         38.84600
# 12       0.07321                  0.90626 -26.81422         29.46328
# 13       0.05267                  0.95893 -47.29133         19.87497
# 14       0.03195                  0.99087 -68.06439         10.10066
# 15       0.00913                  1.00000 -90.87554          0.00000
#
#     kolmogorov_smirnov
# 0              0.01902
# 1              0.03642
# 2              0.05444
# 3              0.07224
# 4              0.08946
# 5              0.17045
# 6              0.24862
# 7              0.31591
# 8              0.42652
# 9              0.48171
# 10             0.50950
# 11             0.49397
# 12             0.43712
# 13             0.33696
# 14             0.19266
# 15             0.00000
# ModelMetricsBinomial: deeplearning
# ** Reported on validation data. **
#
# MSE: 0.17516545283633242
# RMSE: 0.4185277205112374
# LogLoss: 0.5251084360080707
# Mean Per-Class Error: 0.2620502023314213
# AUC: 0.8157249614566904
# AUCPR: 0.8282078748582022
# Gini: 0.6314499229133808
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.39076594795425207:
#                   0           1   Error               Rate
# 0      0 6795.00000  5010.00000  0.4244   (5010.0/11805.0)
# 1      1 1855.00000 11410.00000  0.1398   (1855.0/13265.0)
# 2  Total 8650.00000 16420.00000  0.2738   (6865.0/25070.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold       value       idx
# 0                        max f1    0.39077     0.76874 246.00000
# 1                        max f2    0.13875     0.86410 344.00000
# 2                  max f0point5    0.59839     0.76091 164.00000
# 3                  max accuracy    0.52637     0.73785 193.00000
# 4                 max precision    0.99421     0.97333   1.00000
# 5                    max recall    0.00158     1.00000 399.00000
# 6               max specificity    0.99750     0.99992   0.00000
# 7              max absolute_mcc    0.53896     0.47522 188.00000
# 8    max min_per_class_accuracy    0.53590     0.73766 189.00000
# 9   max mean_per_class_accuracy    0.53896     0.73795 188.00000
# 10                      max tns    0.99750 11804.00000   0.00000
# 11                      max fns    0.99750 13229.00000   0.00000
# 12                      max fps    0.00158 11805.00000 399.00000
# 13                      max tps    0.00158 13265.00000 399.00000
# 14                      max tnr    0.99750     0.99992   0.00000
# 15                      max fnr    0.99750     0.99729   0.00000
# 16                      max fpr    0.00158     1.00000 399.00000
# 17                      max tpr    0.00158     1.00000 399.00000
# Gains/Lift Table: Avg response rate: 52.91 %, avg score: 53.20 %
#     group  cumulative_data_fraction  lower_threshold    lift  cumulative_lift  \
# 0       1                   0.01001          0.98510 1.81464          1.81464
# 1       2                   0.02002          0.97666 1.85982          1.83723
# 2       3                   0.03004          0.96997 1.79205          1.82217
# 3       4                   0.04001          0.96319 1.82190          1.82210
# 4       5                   0.05002          0.95667 1.73934          1.80554
# 5       6                   0.10000          0.91976 1.73910          1.77233
# 6       7                   0.15002          0.88127 1.66085          1.73516
# 7       8                   0.20000          0.83575 1.58676          1.69808
# 8       9                   0.30000          0.74287 1.44968          1.61528
# 9      10                   0.40000          0.64454 1.27252          1.52959
# 10     11                   0.50000          0.54819 1.11798          1.44727
# 11     12                   0.60000          0.44603 0.90991          1.35771
# 12     13                   0.70000          0.34219 0.75989          1.27231
# 13     14                   0.80000          0.23419 0.56012          1.18328
# 14     15                   0.90000          0.10930 0.37618          1.09360
# 15     16                   1.00000          0.00000 0.15756          1.00000
#
#     response_rate   score  cumulative_response_rate  cumulative_score  \
# 7 2300441.00000        0.40419           0.49194      0.34445  ...
#
#    training_pr_auc  training_lift  training_classification_error  \
# 0              nan            nan                            nan
# 1          0.78442        1.83653                        0.32771
# 2          0.82186        1.81759                        0.27769
# 3          0.83099        1.87439                        0.27609
# 4          0.84399        1.87439                        0.26755
# 5          0.85230        1.89333                        0.25449
# 6          0.85646        1.87439                        0.25721
# 7          0.85230        1.89333                        0.25449
#
#    validation_rmse  validation_logloss  validation_r2  validation_auc  \
# 0              nan                 nan            nan             nan
# 1          0.44084             0.57203        0.22001         0.77299
# 2          0.42716             0.54390        0.26767         0.80469
# 3          0.42269             0.53285        0.28291         0.81215
# 4          0.41878             0.52524        0.29609         0.81545
# 5          0.41853             0.52511        0.29695         0.81572
# 6          0.42013             0.52982        0.29155         0.81569
# 7          0.41853             0.52511        0.29695         0.81572
#
#    validation_pr_auc  validation_lift  validation_classification_error
# 0                nan              nan                              nan
# 1            0.78271          1.76193                          0.32078
# 2            0.81686          1.82970                          0.28767
# 3            0.82362          1.83723                          0.28349
# 4            0.82755          1.82217                          0.27483
# 5            0.82821          1.81464                          0.27383
# 6            0.82772          1.82217                          0.28309
# 7            0.82821          1.81464                          0.27383
#
# [8 rows x 21 columns]

# %%
higgs_model_v1.auc(train=True, valid=True, xval=False)
# Out:
# {'train': 0.8391347566024584, 'valid': 0.8157249614566904}

# %% [markdown]
# Highest AUC for any model, although still a 3% difference in training versus validation AUC, meaning it might not necessarily be generalizing the best. Let's include some dropouts and see what it does.

# %%
higgs_model_v2 = H2ODeepLearningEstimator(model_id = 'higgs_v2', epochs = 10, variable_importances = True, activation = 'rectifier_with_dropout',  loss="CrossEntropy", balance_classes=False)
higgs_model_v2.train(higgs_X, higgs_y, training_frame = train, validation_frame = valid)
print(higgs_model_v2)
# Out:
# deeplearning Model Build progress: |██████████████████████████████████████| 100%
# Model Details
# =============
# H2ODeepLearningEstimator :  Deep Learning
# Model Key:  higgs_v2
#
#
# Status of Neuron Layers: predicting label, 2-class classification, bernoulli distribution, CrossEntropy loss, 46,402 weights/biases, 556.6 KB, 2,300,966 training samples, mini-batch size 1
#      layer  units              type  dropout      l1      l2 mean_rate  \
# 0        1     28             Input  0.00000
# 1        2    200  RectifierDropout 50.00000 0.00000 0.00000   0.00395
# 2        3    200  RectifierDropout 50.00000 0.00000 0.00000   0.01838
# 3        4      2           Softmax          0.00000 0.00000   0.00360
#
#   rate_rms momentum mean_weight weight_rms mean_bias bias_rms
# 0
# 1  0.00191  0.00000    -0.01827    0.27192  -0.38930  0.24179
# 2  0.02534  0.00000    -0.07234    0.17190   0.19039  0.38815
# 3  0.00352  0.00000    -0.01102    0.32326  -0.11028  0.05694
# ModelMetricsBinomial: deeplearning
# ** Reported on train data. **
#
# MSE: 0.18225006429873264
# RMSE: 0.42690755943029707
# LogLoss: 0.5404637916392692
# Mean Per-Class Error: 0.2707122074069438
# AUC: 0.8054191468783198
# AUCPR: 0.8185559138927807
# Gini: 0.6108382937566397
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.4404369909370502:
#                   0          1   Error               Rate
# 0      0 2491.00000 2321.00000  0.4823    (2321.0/4812.0)
# 1      1  658.00000 4601.00000  0.1251     (658.0/5259.0)
# 2  Total 3149.00000 6922.00000  0.2958   (2979.0/10071.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold      value       idx
# 0                        max f1    0.44044    0.75544 244.00000
# 1                        max f2    0.28020    0.85824 310.00000
# 2                  max f0point5    0.56815    0.75012 175.00000
# 3                  max accuracy    0.54203    0.72863 189.00000
# 4                 max precision    0.97867    1.00000   0.00000
# 5                    max recall    0.06767    1.00000 384.00000
# 6               max specificity    0.97867    1.00000   0.00000
# 7              max absolute_mcc    0.55195    0.45819 184.00000
# 8    max min_per_class_accuracy    0.53454    0.72675 193.00000
# 9   max mean_per_class_accuracy    0.54203    0.72929 189.00000
# 10                      max tns    0.97867 4812.00000   0.00000
# 11                      max fns    0.97867 5255.00000   0.00000
# 12                      max fps    0.00453 4812.00000 399.00000
# 13                      max tps    0.06767 5259.00000 384.00000
# 14                      max tnr    0.97867    1.00000   0.00000
# 15                      max fnr    0.97867    0.99924   0.00000
# 16                      max fpr    0.00453    1.00000 399.00000
# 17                      max tpr    0.06767    1.00000 384.00000
# Gains/Lift Table: Avg response rate: 52.22 %, avg score: 54.70 %
#     group  cumulative_data_fraction  lower_threshold    lift  cumulative_lift  \
# 0       1                   0.01003          0.94507 1.87708          1.87708
# 1       2                   0.02006          0.93373 1.83916          1.85812
# 2       3                   0.03009          0.92125 1.85812          1.85812
# 3       4                   0.04002          0.91069 1.76180          1.83422
# 4       5                   0.05004          0.90280 1.80124          1.82761
# 5       6                   0.10009          0.86602 1.77822          1.80291
# 6       7                   0.15003          0.82511 1.64850          1.75151
# 7       8                   0.20008          0.77889 1.58064          1.70877
# 8       9                   0.30007          0.67850 1.40725          1.60830
# 9      10                   0.40006          0.59867 1.25321          1.51955
# 10     11                   0.50005          0.53828 1.10488          1.43663
# 11     12                   0.60004          0.48819 0.88809          1.34522
# 12     13                   0.70003          0.43142 0.74736          1.25983
# 13     14                   0.80002          0.35083 0.60474          1.17795
# 14     15                   0.90001          0.23132 0.38794          1.09018
# 15     16                   1.00000          0.00371 0.18827          1.00000
#
#     response_rate   score  cumulative_response_rate  cumulative_score  \
# 0         0.98020 0.95710                   0.98020           0.95710
# 1         0.96040 0.93915                   0.97030           0.94812
# 2         0.97030 0.92743                   0.97030           0.94122
# 3         0.92000 0.91548                   0.95782           0.93484
# 4         0.94059 0.90700                   0.95437           0.92926
# 5         0.92857 0.88456                   0.94147           0.90691
# 6         0.86083 0.84599                   0.91463           0.88663
# 7         0.82540 0.80227                   0.89231           0.86553
# 8         0.73486 0.72804                   0.83984           0.81971
# 9         0.65442 0.63652                   0.79350           0.77393
# 10        0.57696 0.56721                   0.75020           0.73259
# 11        0.46375 0.51340                   0.70247           0.69607
# 12        0.39027 0.46097                   0.65787           0.66248
# 13        0.31579 0.39348                   0.61512           0.62886
# 14        0.20258 0.29639                   0.56929           0.59193
# 15        0.09831 0.14286                   0.52219           0.54702
#
#     capture_rate  cumulative_capture_rate      gain  cumulative_gain  \
# 0        0.01882                  0.01882  87.70820         87.70820
# 1        0.01844                  0.03727  83.91612         85.81216
# 2        0.01863                  0.05590  85.81216         85.81216
# 3        0.01749                  0.07340  76.18026         83.42211
# 4        0.01806                  0.09146  80.12403         82.76118
# 5        0.08899                  0.18045  77.82169         80.29144
# 6        0.08234                  0.26279  64.85015         75.15115
# 7        0.07910                  0.34189  58.06373         70.87718
# 8        0.14071                  0.48260  40.72514         60.82982
# 9        0.12531                  0.60791  25.32144         51.95493
# 10       0.11048                  0.71839  10.48825         43.66324
# 11       0.08880                  0.80719 -11.19103         34.52237
# 12       0.07473                  0.88192 -25.26354         25.98274
# 13       0.06047                  0.94238 -39.52623         17.79514
# 14       0.03879                  0.98118 -61.20550          9.01826
# 15       0.01882                  1.00000 -81.17326          0.00000
#
#     kolmogorov_smirnov
# 0              0.01841
# 1              0.03602
# 2              0.05403
# 3              0.06987
# 4              0.08668
# 5              0.16819
# 6              0.23598
# 7              0.29679
# 8              0.38202
# 9              0.43501
# 10             0.45696
# 11             0.43354
# 12             0.38067
# 13             0.29795
# 14             0.16987
# 15             0.00000
# ModelMetricsBinomial: deeplearning
# ** Reported on validation data. **
#
# MSE: 0.18095743547840645
# RMSE: 0.42539092077571006
# LogLoss: 0.5382972403064139
# Mean Per-Class Error: 0.269135050935281
# AUC: 0.8084175842105659
# AUCPR: 0.8208983118537676
# Gini: 0.6168351684211317
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.43591182277995993:
#                   0           1   Error               Rate
# 0      0 6017.00000  5788.00000  0.4903   (5788.0/11805.0)
# 1      1 1513.00000 11752.00000  0.1141   (1513.0/13265.0)
# 2  Total 7530.00000 17540.00000  0.2912   (7301.0/25070.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold       value       idx
# 0                        max f1    0.43591     0.76299 247.00000
# 1                        max f2    0.26084     0.86336 321.00000
# 2                  max f0point5    0.57309     0.75300 175.00000
# 3                  max accuracy    0.51457     0.73167 206.00000
# 4                 max precision    0.98848     1.00000   0.00000
# 5                    max recall    0.04955     1.00000 392.00000
# 6               max specificity    0.98848     1.00000   0.00000
# 7              max absolute_mcc    0.54246     0.46095 191.00000
# 8    max min_per_class_accuracy    0.53552     0.72929 195.00000
# 9   max mean_per_class_accuracy    0.54246     0.73086 191.00000
# 10                      max tns    0.98848 11805.00000   0.00000
# 11                      max fns    0.98848 13263.00000   0.00000
# 12                      max fps    0.00067 11805.00000 399.00000
# 13                      max tps    0.04955 13265.00000 392.00000
# 14                      max tnr    0.98848     1.00000   0.00000
# 15                      max fnr    0.98848     0.99985   0.00000
# 16                      max fpr    0.00067     1.00000 399.00000
# 17                      max tpr    0.04955     1.00000 392.00000
# Gains/Lift Table: Avg response rate: 52.91 %, avg score: 54.97 %
#     group  cumulative_data_fraction  lower_threshold    lift  cumulative_lift  \
# 0       1                   0.01001          0.94770 1.83723          1.83723
# 1       2                   0.02002          0.93383 1.82217          1.82970
# 2       3                   0.03004          0.92225 1.80711          1.82217
# 3       4                   0.04001          0.91302 1.81434          1.82022
# 4       5                   0.05002          0.90330 1.73934          1.80403
# 5       6                   0.10000          0.86738 1.71949          1.76178
# 6       7                   0.15002          0.82640 1.63523          1.71959
# 7       8                   0.20000          0.77765 1.59129          1.68752
# 8       9                   0.30000          0.67906 1.43159          1.60221
# 9      10                   0.40000          0.60144 1.23407          1.51018
# 10     11                   0.50000          0.54100 1.13080          1.43430
# 11     12                   0.60000          0.49266 0.92348          1.34916
# 12     13                   0.70000          0.43424 0.76593          1.26584
# 13     14                   0.80000          0.35615 0.58349          1.18055
# 14     15                   0.90000          0.23706 0.38749          1.09243
# 15     16                   1.00000          0.00014 0.16811          1.00000
#
#     response_rate   score  cumulative_response_rate  cumulative_score  \
# 0         0.97211 0.95926                   0.97211           0.95926
# 1         0.96414 0.94065                   0.96813           0.94995
# 2         0.95618 0.92816                   0.96414           0.94269
# 3         0.96000 0.91754                   0.96311           0.93642
# 4         0.92032 0.90813                   0.95455           0.93076
# 5         0.90982 0.88506                   0.93219           0.90792
# 6         0.86523 0.84785                   0.90986           0.88789
# 7         0.84198 0.80139                   0.89290           0.86627
# 8         0.75748 0.72759                   0.84776           0.82005
# 9         0.65297 0.63775                   0.79906           0.77447
# 10        0.59832 0.57078                   0.75892           0.73373
# 11        0.48863 0.51687                   0.71387           0.69759
# 12        0.40527 0.46485                   0.66978           0.66434
# 13        0.30874 0.39792                   0.62465           0.63104
# 14        0.20503 0.30192                   0.57803           0.59447
# 15        0.08895 0.14670                   0.52912           0.54969
#
#     capture_rate  cumulative_capture_rate      gain  cumulative_gain  \
# 0        0.01839                  0.01839  83.72285         83.72285
# 1        0.01824                  0.03664  82.21693         82.96989
# 2        0.01809                  0.05473  80.71100         82.21693
# 3        0.01809                  0.07282  81.43385         82.02174
# 4        0.01741                  0.09024  73.93434         80.40297
# 5        0.08594                  0.17618  71.94948         76.17791
# 6        0.08179                  0.25797  63.52316         71.95854
# 7        0.07953                  0.33750  59.12868         68.75236
# 8        0.14316                  0.48066  43.15869         60.22113
# 9        0.12341                  0.60407  23.40746         51.01772
# 10       0.11308                  0.71715  13.07953         43.43008
# 11       0.09235                  0.80950  -7.65172         34.91645
# 12       0.07659                  0.88609 -23.40746         26.58446
# 13       0.05835                  0.94444 -41.65096         18.05503
# 14       0.03875                  0.98319 -61.25141          9.24320
# 15       0.01681                  1.00000 -83.18884          0.00000
#
#     kolmogorov_smirnov
# 0              0.01780
# 1              0.03528
# 2              0.05244
# 3              0.06969
# 4              0.08541
# 5              0.16178
# 6              0.22926
# 7              0.29202
# 8              0.38367
# 9              0.43338
# 10             0.46116
# 11             0.44491
# 12             0.39520
# 13             0.30674
# 14             0.17667
# 15             0.00000
# Scoring History:
#                timestamp    duration  training_speed   epochs  iterations  \
# 0    2020-07-22 20:07:46   0.000 sec            None  0.00000           0
# 1    2020-07-22 20:07:48   1.583 sec   76801 obs/sec  0.44559           1
# 2    2020-07-22 20:07:53   6.605 sec   97674 obs/sec  2.66886           6
# 3    2020-07-22 20:07:58  11.820 sec  107511 obs/sec  5.33853          12
# 4    2020-07-22 20:08:03  17.027 sec  111205 obs/sec  8.00730          18
# 5    2020-07-22 20:08:07  20.970 sec  115261 obs/sec 10.22970          23
#
#         samples  training_rmse  training_logloss  training_r2  ...  \
# 0       0.00000            nan               nan          nan  ...
# 1  100226.00000        0.46814           0.62680      0.12163  ...
# 2  600306.00000        0.43792           0.56349      0.23139  ...
# 3 1200796.00000        0.43146           0.54983      0.25390  ...
# 4 1801081.00000        0.43164           0.54922      0.25327  ...
# 5 2300966.00000        0.42691           0.54046      0.26956  ...
#
#    training_pr_auc  training_lift  training_classification_error  \
# 0              nan            nan                            nan
# 1          0.70859        1.82020                        0.37970
# 2          0.79328        1.91500                        0.32896
# 3          0.81146        1.91500                        0.30543
# 4          0.81692        1.89604                        0.30106
# 5          0.81856        1.87708                        0.29580
#
#    validation_rmse  validation_logloss  validation_r2  validation_auc  \
# 0              nan                 nan            nan             nan
# 1          0.46731             0.62546        0.12351         0.71295
# 2          0.43735             0.56278        0.23228         0.78022
# 3          0.43072             0.54903        0.25540         0.79792
# 4          0.43050             0.54784        0.25616         0.80499
# 5          0.42539             0.53830        0.27371         0.80842
#
#    validation_pr_auc  validation_lift  validation_classification_error
# 0                nan              nan                              nan
# 1            0.71899          1.76946                          0.36837
# 2            0.79564          1.83723                          0.31504
# 3            0.81242          1.82217                          0.28656
# 4            0.81771          1.83723                          0.28365
# 5            0.82090          1.83723                          0.29122
#
# [6 rows x 21 columns]
# Variable Importances:
#                     variable  relative_importance  scaled_importance  \
# 0                       m_bb              1.00000            1.00000
# 1                      m_wbb              0.71856            0.71856
# 2                     m_wwbb              0.65568            0.65568
# 3                      m_jjj              0.58382            0.58382
# 4                       m_jj              0.45474            0.45474
# 5                      m_jlv              0.37084            0.37084
# 6                   jet_1_pt              0.36807            0.36807
# 7                  lepton_pT              0.32801            0.32801
# 8   missing_energy_magnitude              0.21347            0.21347
# 9                   jet_2_pt              0.20680            0.20680
# 10               jet_4_b_tag              0.19201            0.19201
# 11                      m_lv              0.18259            0.18259
# 12               jet_3_b-tag              0.17592            0.17592
# 13               jet_2_b_tag              0.15930            0.15930
# 14               jet_1_b_tag              0.15916            0.15916
# 15                  jet_3_pt              0.13661            0.13661
# 16                  jet_4_pt              0.11796            0.11796
# 17                 jet_1_eta              0.09717            0.09717
# 18                lepton_eta              0.09483            0.09483
# 19                 jet_2_eta              0.08001            0.08001
#
#     percentage
# 0      0.14757
# 1      0.10604
# 2      0.09676
# 3      0.08616
# 4      0.06711
# 5      0.05473
# 6      0.05432
# 7      0.04841
# 8      0.03150
# 9      0.03052
# 10     0.02834
# 11     0.02695
# 12     0.02596
# 13     0.02351
# 14     0.02349
# 15     0.02016
# 16     0.01741
# 17     0.01434
# 18     0.01399
# 19     0.01181
# See the whole table with table.as_data_frame()

# %%
higgs_model_v2.auc(train=True, valid=True, xval=False)
# Out:
# {'train': 0.8054191468783198, 'valid': 0.8084175842105659}

# %% [markdown]
# Not our best model, however we are getting comparable AUC for the validation set, and it seems to be a better model for generalizing.

# %% [markdown]
# ### Model Comparison

# %%
H2O_optimized = higgs_model_v2.auc(valid=True)

# %%
H2O_defaults = higgs_model_v1.auc(valid=True)

# %%
NN_paper_optimized = auc_keras2

# %%
NN_paper = auc_keras

# %%
Random_forest = auc_rf

# %%
from tabulate import tabulate

results = [("NN_paper",NN_paper),("Random_forest",Random_forest),("NN_paper_optimized",NN_paper_optimized),("H2O_defaults",H2O_defaults),("H2O_optimized",H2O_optimized)]
headers = ["Model","AUC"]

print(tabulate(results, headers = headers,))
# Out:
# Model                    AUC
# ------------------  --------
# NN_paper            0.8038
# Random_forest       0.77775
# NN_paper_optimized  0.809925
# H2O_defaults        0.815725
# H2O_optimized       0.808418
